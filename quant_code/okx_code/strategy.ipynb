# %%
import pandas as pd
import backtrader as bt

# 1. 读取Excel文件
df = pd.read_excel('D:/code/quant_code/行情数据/btc_usdt_candlesticks.xlsx')

# 2. 检查列名
print("列名:", df.columns)

# 3. 格式化数据
# 将时间戳转换为datetime格式
df['date'] = pd.to_datetime(df['ts'], unit='ms')

# 4. 创建Backtrader数据源
class PandasData(bt.feeds.PandasData):
    lines = ('close', 'high', 'open',)
    # params = (
    #     ('datetime', 'date'),  # 时间列
    #     ('open', 'o'),         # 开盘价
    #     ('high', 'h'),         # 最高价
    #     ('low', 'l'),          # 最低价
    #     ('close', 'c'),        # 收盘价
    #     ('volume', 'vol'),     # 成交量
    #     ('volCcy', 'volCcy'),  # 货币成交量
    #     ('volCcyQuote', 'volCcyQuote'),  # 货币成交量（报价）
    #     ('confirm', 'confirm'), # 确认
    # )

# 创建回测引擎
cerebro = bt.Cerebro()

# 不再设置索引，直接使用原始数据
data = PandasData(dataname=df)
cerebro.adddata(data)

# 添加你的策略
class MyStrategy(bt.Strategy):
    def __init__(self):
        self.ma = bt.indicators.SimpleMovingAverage(self.data.close, period=20)

    def next(self):
        if self.data.close[0] > self.ma[0]:
            self.buy()
        elif self.data.close[0] < self.ma[0]:
            self.sell()

cerebro.addstrategy(MyStrategy)

# 运行回测
try:
    cerebro.run()
except Exception as e:
    print("回测失败:", e)
# 设置图表大小
cerebro.plot(size=(12, 8))  # 设置图表尺寸
# 可选：绘制结果
cerebro.plot()
# Out:
# 列名: Index(['ts', 'open', 'high', 'low', 'close', 'vol', 'volCcy', 'volCcyQuote',
#        'confirm', 'date'],
#       dtype='object')
# 回测失败: 'int' object has no attribute 'to_pydatetime'
# []

# %%
import pandas as pd
import backtrader as bt

# 1. 读取Excel文件
df = pd.read_excel('D:/code/quant_code/行情数据/btc_usdt_candlesticks.xlsx', index_col='date')

# 2.创建策略
class MyStrategt(bt.Strategy):
    
    params = (
        ('myparam',20),
        ('exitbars',5)
    )
    
    def log(self, txt, dt=None):
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))
    
    def __init__(self):
        self.dataclose = self.datas[0].close
        # 跟踪订单
        self.order = None
        
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # 订单提交和成交当前不做处理
            return 
        # 检查订单是否成交
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log('购买完成, %.2f' % order.executed.price)
            elif order.issell():
                self.log('出售完成, %.2f' % order.executed.price)
            
            self.bar_executed = len(self)
            
        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('订单取消')
            
        # 记录没有挂起的订单   
        self.order = None
        
    def next(self):
        self.log('Close, %.2f' % self.dataclose[0])
        
        # 检查如果有挂起的订单，不能再发起一个
        if self.order:
            return 
        
        if self.dataclose[0] < self.dataclose[-1]:
            # 连续两天下跌就买入
            if self.dataclose[-1] < self.dataclose[-2]:
                self.log('买！，%.2f' % self.dataclose[0])
                self.order = self.buy()
        else:
            # 已经在市场5天，5天后卖掉
            if(len(self) >= (self.bar_executed + self.params.exitbars)):
                self.log('卖出！，%.2f' % self.dataclose[0])
                self.order = self.sell()
        

# 3.创建大脑
cerebro = bt.Cerebro()
# 4.添加策略
cerebro.addstrategy(MyStrategt, myparam=20, exitbars=7)
# 5.喂数据
data = bt.feeds.PandasData(dataname = df)
cerebro.adddata(data)

# 券商佣金 0.1%
cerebro.broker.setcommission(commission=0.01)
cerebro.broker.setcash(500000)

print('初始资产：%.2f' % cerebro.broker.getvalue())

cerebro.run()

cerebro.plot()

print('结束资产：%.2f' % cerebro.broker.getvalue())
# Out:
# 初始资产：500000.00
# 2023-08-22, Close, 26145.90
# 2023-08-23, Close, 26001.90
# 2023-08-23, 买！，26001.90
# 2023-08-24, 购买完成, 26001.90
# 2023-08-24, Close, 25932.30
# 2023-08-24, 买！，25932.30
# 2023-08-25, 购买完成, 25932.30
# 2023-08-25, Close, 26055.40
# 2023-08-26, Close, 26123.20
# 2023-08-27, Close, 26104.50
# 2023-08-28, Close, 27420.50
# 2023-08-29, Close, 27204.00
# 2023-08-30, Close, 26923.50
# 2023-08-30, 买！，26923.50
# 2023-08-31, 购买完成, 26923.50
# 2023-08-31, Close, 25810.40
# 2023-08-31, 买！，25810.40
# 2023-09-01, 购买完成, 25810.40
# 2023-09-01, Close, 25898.20
# 2023-09-02, Close, 25872.10
# 2023-09-03, Close, 25815.20
# 2023-09-03, 买！，25815.20
# 2023-09-04, 购买完成, 25815.20
# 2023-09-04, Close, 25758.70
# 2023-09-04, 买！，25758.70
# 2023-09-05, 购买完成, 25758.60
# 2023-09-05, Close, 25592.10
# 2023-09-05, 买！，25592.10
# 2023-09-06, 购买完成, 25591.00
# 2023-09-06, Close, 25776.10
# 2023-09-07, Close, 25846.30
# 2023-09-08, Close, 25893.60
# 2023-09-09, Close, 25774.50
# 2023-09-10, Close, 25114.00
# 2023-09-10, 买！，25114.00
# 2023-09-11, 购买完成, 25112.90
# 2023-09-11, Close, 26209.20
# 2023-09-12, Close, 26246.10
# 2023-09-13, Close, 26696.40
# 2023-09-14, Close, 26320.90
# 2023-09-15, Close, 26510.40
# 2023-09-16, Close, 26548.70
# 2023-09-17, Close, 27271.80
# 2023-09-18, Close, 27425.10
# 2023-09-18, 卖出！，27425.10
# 2023-09-19, 出售完成, 27425.60
# 2023-09-19, Close, 27180.20
# 2023-09-20, Close, 26587.10
# 2023-09-20, 买！，26587.10
# 2023-09-21, 购买完成, 26587.20
# 2023-09-21, Close, 26633.20
# 2023-09-22, Close, 26577.80
# 2023-09-23, Close, 26576.70
# 2023-09-23, 买！，26576.70
# 2023-09-24, 购买完成, 26576.80
# 2023-09-24, Close, 26244.50
# 2023-09-24, 买！，26244.50
# 2023-09-25, 购买完成, 26244.50
# 2023-09-25, Close, 26124.40
# 2023-09-25, 买！，26124.40
# 2023-09-26, 购买完成, 26124.50
# 2023-09-26, Close, 26300.10
# 2023-09-27, Close, 27027.30
# 2023-09-28, Close, 26887.80
# 2023-09-29, Close, 26994.80
# 2023-09-30, Close, 27153.00
# 2023-10-01, Close, 28026.10
# 2023-10-02, Close, 27339.10
# 2023-10-03, Close, 27402.90
# 2023-10-03, 卖出！，27402.90
# 2023-10-04, 出售完成, 27402.90
# 2023-10-04, Close, 27549.70
# 2023-10-05, Close, 27946.00
# 2023-10-06, Close, 27942.00
# 2023-10-07, Close, 27898.10
# 2023-10-07, 买！，27898.10
# 2023-10-08, 购买完成, 27898.20
# 2023-10-08, Close, 27443.50
# 2023-10-08, 买！，27443.50
# 2023-10-09, 购买完成, 27443.60
# 2023-10-09, Close, 27409.80
# 2023-10-09, 买！，27409.80
# 2023-10-10, 购买完成, 27409.80
# 2023-10-10, Close, 26775.70
# 2023-10-10, 买！，26775.70
# 2023-10-11, 购买完成, 26775.60
# 2023-10-11, Close, 26674.70
# 2023-10-11, 买！，26674.70
# 2023-10-12, 购买完成, 26674.70
# 2023-10-12, Close, 26704.40
# 2023-10-13, Close, 26948.40
# 2023-10-14, Close, 26899.50
# 2023-10-15, Close, 28066.00
# 2023-10-16, Close, 28461.50
# 2023-10-17, Close, 28249.30
# 2023-10-18, Close, 28677.10
# 2023-10-19, Close, 29550.90
# 2023-10-19, 卖出！，29550.90
# 2023-10-20, 出售完成, 29550.90
# 2023-10-20, Close, 29933.80
# 2023-10-21, Close, 29827.10
# 2023-10-22, Close, 30885.00
# 2023-10-23, Close, 33674.80
# 2023-10-24, Close, 34843.10
# 2023-10-25, Close, 34048.00
# 2023-10-26, Close, 34002.40
# 2023-10-26, 买！，34002.40
# 2023-10-27, 购买完成, 34003.00
# 2023-10-27, Close, 34195.30
# 2023-10-28, Close, 34448.30
# 2023-10-29, Close, 34656.50
# 2023-10-30, Close, 34272.50
# 2023-10-31, Close, 34291.80
# 2023-11-01, Close, 34637.90
# 2023-11-02, Close, 34762.90
# 2023-11-03, Close, 34709.80
# 2023-11-04, Close, 34884.90
# 2023-11-04, 卖出！，34884.90
# 2023-11-05, 出售完成, 34885.00
# 2023-11-05, Close, 35079.30
# 2023-11-06, Close, 34723.50
# 2023-11-07, Close, 35221.20
# 2023-11-08, Close, 37087.10
# 2023-11-09, Close, 37084.10
# 2023-11-10, Close, 37049.90
# 2023-11-10, 买！，37049.90
# 2023-11-11, 购买完成, 37050.00
# 2023-11-11, Close, 37154.50
# 2023-11-12, Close, 36838.20
# 2023-11-13, Close, 36143.90
# 2023-11-13, 买！，36143.90
# 2023-11-14, 购买完成, 36146.00
# 2023-11-14, Close, 36411.90
# 2023-11-15, Close, 36401.90
# 2023-11-16, Close, 36042.80
# 2023-11-16, 买！，36042.80
# 2023-11-17, 购买完成, 36043.20
# 2023-11-17, Close, 36665.70
# 2023-11-18, Close, 36571.10
# 2023-11-19, Close, 37462.70
# 2023-11-20, Close, 36974.90
# 2023-11-21, Close, 36480.10
# 2023-11-21, 买！，36480.10
# 2023-11-22, 订单取消
# 2023-11-22, Close, 36949.40
# 2023-11-23, Close, 38216.70
# 2023-11-24, Close, 37702.10
# 2023-11-25, Close, 37439.70
# 2023-11-25, 买！，37439.70
# 2023-11-26, 订单取消
# 2023-11-26, Close, 36748.90
# 2023-11-26, 买！，36748.90
# 2023-11-27, 订单取消
# 2023-11-27, Close, 37517.50
# 2023-11-27, 卖出！，37517.50
# 2023-11-28, 出售完成, 37517.60
# 2023-11-28, Close, 37826.90
# 2023-11-29, Close, 37616.60
# 2023-11-30, Close, 38413.50
# 2023-12-01, Close, 38808.00
# 2024-09-02, Close, 57724.00
# 2024-09-03, Close, 58128.70
# 2024-09-04, Close, 55976.10
# 2024-09-05, Close, 54044.00
# 2024-09-05, 买！，54044.00
# 2024-09-06, 订单取消
# 2024-09-06, Close, 54784.10
# 2024-09-06, 卖出！，54784.10
# 2024-09-07, 出售完成, 54784.10
# 2024-09-07, Close, 53687.90
# 2024-09-08, Close, 55383.90
# 2024-09-09, Close, 56592.20
# 2024-09-10, Close, 56700.40
# 2024-09-11, Close, 57514.20
# 2024-09-12, Close, 59660.10
# 2024-09-13, Close, 59875.30
# 2024-09-14, Close, 60334.20
# 2024-09-14, 卖出！，60334.20
# 2024-09-15, 出售完成, 60334.20
# 2024-09-15, Close, 57881.80
# 2024-09-16, Close, 61134.00
# 2024-09-17, Close, 59430.00
# 2024-09-18, Close, 63156.20
# 2024-09-19, Close, 63160.00
# 2024-09-20, Close, 63170.10
# 2024-09-21, Close, 62656.10
# 2024-09-22, Close, 63616.10
# 2024-09-22, 卖出！，63616.10
# 2024-09-23, 出售完成, 63616.00
# 2024-09-23, Close, 63160.00
# 2024-09-24, Close, 63499.00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 78
#      74 print('初始资产：%.2f' % cerebro.broker.getvalue())
#      76 cerebro.run()
# ---> 78 cerebro.plot()
#      80 print('结束资产：%.2f' % cerebro.broker.getvalue())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\backtrader\cerebro.py:994, in Cerebro.plot(self, plotter, numfigs, iplot, start, end, width, height, dpi, tight, use, **kwargs)
#     992 for stratlist in self.runstrats:
#     993     for si, strat in enumerate(stratlist):
# --> 994         rfig = plotter.plot(strat, figid=si * 100,
#     995                             numfigs=numfigs, iplot=iplot,
#     996                             start=start, end=end, use=use)
#     997         # pfillers=pfillers2)
#     999         figs.append(rfig)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\backtrader\plot\plot.py:223, in Plot_OldSync.plot(self, strategy, figid, numfigs, iplot, start, end, **kwargs)
#     215 for ind in self.dplotsup[data]:
#     216     self.plotind(
#     217         data,
#     218         ind,
#     219         subinds=self.dplotsover[ind],
#     220         upinds=self.dplotsup[ind],
#     221         downinds=self.dplotsdown[ind])
# --> 223 self.plotdata(data, self.dplotsover[data])
#     225 for ind in self.dplotsdown[data]:
#     226     self.plotind(
#     227         data,
#     228         ind,
#     229         subinds=self.dplotsover[ind],
#     230         upinds=self.dplotsup[ind],
#     231         downinds=self.dplotsdown[ind])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\backtrader\plot\plot.py:674, in Plot_OldSync.plotdata(self, data, indicators)
#     672 axdatamaster = None
#     673 if self.pinf.sch.volume and voloverlay:
# --> 674     volplot = self.plotvolume(
#     675         data, opens, highs, lows, closes, volumes, vollabel)
#     676     axvol = self.pinf.daxis[data.volume]
#     677     ax = axvol.twinx()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\backtrader\plot\plot.py:617, in Plot_OldSync.plotvolume(self, data, opens, highs, lows, closes, volumes, label)
#     614     prune = None
#     616     volylim /= self.pinf.sch.volscaling
# --> 617     ax.set_ylim(0, volylim, auto=True)
#     618 else:
#     619     # plot a legend
#     620     handles, labels = ax.get_legend_handles_labels()
#
# File C:\Users\wang\Anconda3\Lib\site-packages\matplotlib\axes\_base.py:3898, in _AxesBase.set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    3896         raise TypeError("Cannot pass both 'top' and 'ymax'")
#    3897     top = ymax
# -> 3898 return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#
# File C:\Users\wang\Anconda3\Lib\site-packages\matplotlib\axis.py:1211, in Axis._set_lim(self, v0, v1, emit, auto)
#    1209 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
#    1210 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
# -> 1211 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1213 if v0 is None or v1 is None:
#    1214     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    1215     # so only grab the limits if we really need them.
#    1216     old0, old1 = self.get_view_interval()
#
# File C:\Users\wang\Anconda3\Lib\site-packages\matplotlib\axes\_base.py:3585, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3582     converted_limit = converted_limit.squeeze()
#    3583 if (isinstance(converted_limit, Real)
#    3584         and not np.isfinite(converted_limit)):
# -> 3585     raise ValueError("Axis limits cannot be NaN or Inf")
#    3586 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
#创建一个策略
class TestStrategy(bt.Strategy):
    params = (
        ('maperiod', 20),
    )
 #记录功能
    def log(self, txt, dt=None):
        ''' Logging function fot this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), txt))

    def __init__(self):
        # 引用到close line
        self.dataclose = self.datas[0].close

        # 跟踪订单状态以及买卖价格和佣金
        self.order = None
        self.buyprice = None
        self.buycomm = None

        # 增加移动均线
        self.sma = bt.indicators.SimpleMovingAverage(
            self.datas[0], period=self.params.maperiod)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # 订单状态为提交和接受，不做处理
            return

        # 检查订单是否成交
        # 注意，没有足够现金的话，订单会被拒绝。
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None

    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))

    def next(self):
        # 记录当前处理的close值
        self.log('Close, %.2f' % self.dataclose[0])

        # 订单是否
        if self.order:
            return

        # Check if we are in the market
        if not self.position:

            # 大于均线就买
            if self.dataclose[0] > self.sma[0]:

                # BUY, BUY, BUY!!! (with all possible default parameters)
                self.log('BUY CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.buy()

        else:

            if self.dataclose[0] < self.sma[0]:
                # 小于均线卖卖卖！
                self.log('SELL CREATE, %.2f' % self.dataclose[0])

                # Keep track of the created order to avoid a 2nd order
                self.order = self.sell()


if __name__ == '__main__':
    cerebro = bt.Cerebro()

    # 增加一个策略
    cerebro.addstrategy(TestStrategy)

    #获取数据
    df = pd.read_excel('D:/code/quant_code/行情数据/btc_usdt_candlesticks.xlsx', index_col='date')
    # start_date = datetime(2020, 9, 30)  # 回测开始时间
    # end_date = datetime(2021, 9, 30)  # 回测结束时间
    data = bt.feeds.PandasData(dataname=df)  # 加载数据
    cerebro.adddata(data)  # 将数据传入回测系统

    cerebro.broker.setcash(100000.0)
    # Set the commission - 0.1% ... divide by 100 to remove the %
    cerebro.broker.setcommission(commission=0)
     # Add a FixedSize sizer according to the stake 每次买卖的股数量
    cerebro.addsizer(bt.sizers.FixedSize, stake=70)



    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    cerebro.run()

    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    cerebro.plot()
# Out:
# Starting Portfolio Value: 100000.00
# 2023-09-10, Close, 25114.00
# 2023-09-11, Close, 26209.20
# 2023-09-11, BUY CREATE, 26209.20
# 2023-09-12, Order Canceled/Margin/Rejected
# 2023-09-12, Close, 26246.10
# 2023-09-12, BUY CREATE, 26246.10
# 2023-09-13, Order Canceled/Margin/Rejected
# 2023-09-13, Close, 26696.40
# 2023-09-13, BUY CREATE, 26696.40
# 2023-09-14, Order Canceled/Margin/Rejected
# 2023-09-14, Close, 26320.90
# 2023-09-14, BUY CREATE, 26320.90
# 2023-09-15, Order Canceled/Margin/Rejected
# 2023-09-15, Close, 26510.40
# 2023-09-15, BUY CREATE, 26510.40
# 2023-09-16, Order Canceled/Margin/Rejected
# 2023-09-16, Close, 26548.70
# 2023-09-16, BUY CREATE, 26548.70
# 2023-09-17, Order Canceled/Margin/Rejected
# 2023-09-17, Close, 27271.80
# 2023-09-17, BUY CREATE, 27271.80
# 2023-09-18, Order Canceled/Margin/Rejected
# 2023-09-18, Close, 27425.10
# 2023-09-18, BUY CREATE, 27425.10
# 2023-09-19, Order Canceled/Margin/Rejected
# 2023-09-19, Close, 27180.20
# 2023-09-19, BUY CREATE, 27180.20
# 2023-09-20, Order Canceled/Margin/Rejected
# 2023-09-20, Close, 26587.10
# 2023-09-20, BUY CREATE, 26587.10
# 2023-09-21, Order Canceled/Margin/Rejected
# 2023-09-21, Close, 26633.20
# 2023-09-21, BUY CREATE, 26633.20
# 2023-09-22, Order Canceled/Margin/Rejected
# 2023-09-22, Close, 26577.80
# 2023-09-22, BUY CREATE, 26577.80
# 2023-09-23, Order Canceled/Margin/Rejected
# 2023-09-23, Close, 26576.70
# 2023-09-23, BUY CREATE, 26576.70
# 2023-09-24, Order Canceled/Margin/Rejected
# 2023-09-24, Close, 26244.50
# 2023-09-25, Close, 26124.40
# 2023-09-26, Close, 26300.10
# 2023-09-27, Close, 27027.30
# 2023-09-27, BUY CREATE, 27027.30
# 2023-09-28, Order Canceled/Margin/Rejected
# 2023-09-28, Close, 26887.80
# 2023-09-28, BUY CREATE, 26887.80
# 2023-09-29, Order Canceled/Margin/Rejected
# 2023-09-29, Close, 26994.80
# 2023-09-29, BUY CREATE, 26994.80
# 2023-09-30, Order Canceled/Margin/Rejected
# 2023-09-30, Close, 27153.00
# 2023-09-30, BUY CREATE, 27153.00
# 2023-10-01, Order Canceled/Margin/Rejected
# 2023-10-01, Close, 28026.10
# 2023-10-01, BUY CREATE, 28026.10
# 2023-10-02, Order Canceled/Margin/Rejected
# 2023-10-02, Close, 27339.10
# 2023-10-02, BUY CREATE, 27339.10
# 2023-10-03, Order Canceled/Margin/Rejected
# 2023-10-03, Close, 27402.90
# 2023-10-03, BUY CREATE, 27402.90
# 2023-10-04, Order Canceled/Margin/Rejected
# 2023-10-04, Close, 27549.70
# 2023-10-04, BUY CREATE, 27549.70
# 2023-10-05, Order Canceled/Margin/Rejected
# 2023-10-05, Close, 27946.00
# 2023-10-05, BUY CREATE, 27946.00
# 2023-10-06, Order Canceled/Margin/Rejected
# 2023-10-06, Close, 27942.00
# 2023-10-06, BUY CREATE, 27942.00
# 2023-10-07, Order Canceled/Margin/Rejected
# 2023-10-07, Close, 27898.10
# 2023-10-07, BUY CREATE, 27898.10
# 2023-10-08, Order Canceled/Margin/Rejected
# 2023-10-08, Close, 27443.50
# 2023-10-08, BUY CREATE, 27443.50
# 2023-10-09, Order Canceled/Margin/Rejected
# 2023-10-09, Close, 27409.80
# 2023-10-09, BUY CREATE, 27409.80
# 2023-10-10, Order Canceled/Margin/Rejected
# 2023-10-10, Close, 26775.70
# 2023-10-11, Close, 26674.70
# 2023-10-12, Close, 26704.40
# 2023-10-13, Close, 26948.40
# 2023-10-14, Close, 26899.50
# 2023-10-15, Close, 28066.00
# 2023-10-15, BUY CREATE, 28066.00
# 2023-10-16, Order Canceled/Margin/Rejected
# 2023-10-16, Close, 28461.50
# 2023-10-16, BUY CREATE, 28461.50
# 2023-10-17, Order Canceled/Margin/Rejected
# 2023-10-17, Close, 28249.30
# 2023-10-17, BUY CREATE, 28249.30
# 2023-10-18, Order Canceled/Margin/Rejected
# 2023-10-18, Close, 28677.10
# 2023-10-18, BUY CREATE, 28677.10
# 2023-10-19, Order Canceled/Margin/Rejected
# 2023-10-19, Close, 29550.90
# 2023-10-19, BUY CREATE, 29550.90
# 2023-10-20, Order Canceled/Margin/Rejected
# 2023-10-20, Close, 29933.80
# 2023-10-20, BUY CREATE, 29933.80
# 2023-10-21, Order Canceled/Margin/Rejected
# 2023-10-21, Close, 29827.10
# 2023-10-21, BUY CREATE, 29827.10
# 2023-10-22, Order Canceled/Margin/Rejected
# 2023-10-22, Close, 30885.00
# 2023-10-22, BUY CREATE, 30885.00
# 2023-10-23, Order Canceled/Margin/Rejected
# 2023-10-23, Close, 33674.80
# 2023-10-23, BUY CREATE, 33674.80
# 2023-10-24, Order Canceled/Margin/Rejected
# 2023-10-24, Close, 34843.10
# 2023-10-24, BUY CREATE, 34843.10
# 2023-10-25, Order Canceled/Margin/Rejected
# 2023-10-25, Close, 34048.00
# 2023-10-25, BUY CREATE, 34048.00
# 2023-10-26, Order Canceled/Margin/Rejected
# 2023-10-26, Close, 34002.40
# 2023-10-26, BUY CREATE, 34002.40
# 2023-10-27, Order Canceled/Margin/Rejected
# 2023-10-27, Close, 34195.30
# 2023-10-27, BUY CREATE, 34195.30
# 2023-10-28, Order Canceled/Margin/Rejected
# 2023-10-28, Close, 34448.30
# 2023-10-28, BUY CREATE, 34448.30
# 2023-10-29, Order Canceled/Margin/Rejected
# 2023-10-29, Close, 34656.50
# 2023-10-29, BUY CREATE, 34656.50
# 2023-10-30, Order Canceled/Margin/Rejected
# 2023-10-30, Close, 34272.50
# 2023-10-30, BUY CREATE, 34272.50
# 2023-10-31, Order Canceled/Margin/Rejected
# 2023-10-31, Close, 34291.80
# 2023-10-31, BUY CREATE, 34291.80
# 2023-11-01, Order Canceled/Margin/Rejected
# 2023-11-01, Close, 34637.90
# 2023-11-01, BUY CREATE, 34637.90
# 2023-11-02, Order Canceled/Margin/Rejected
# 2023-11-02, Close, 34762.90
# 2023-11-02, BUY CREATE, 34762.90
# 2023-11-03, Order Canceled/Margin/Rejected
# 2023-11-03, Close, 34709.80
# 2023-11-03, BUY CREATE, 34709.80
# 2023-11-04, Order Canceled/Margin/Rejected
# 2023-11-04, Close, 34884.90
# 2023-11-04, BUY CREATE, 34884.90
# 2023-11-05, Order Canceled/Margin/Rejected
# 2023-11-05, Close, 35079.30
# 2023-11-05, BUY CREATE, 35079.30
# 2023-11-06, Order Canceled/Margin/Rejected
# 2023-11-06, Close, 34723.50
# 2023-11-06, BUY CREATE, 34723.50
# 2023-11-07, Order Canceled/Margin/Rejected
# 2023-11-07, Close, 35221.20
# 2023-11-07, BUY CREATE, 35221.20
# 2023-11-08, Order Canceled/Margin/Rejected
# 2023-11-08, Close, 37087.10
# 2023-11-08, BUY CREATE, 37087.10
# 2023-11-09, Order Canceled/Margin/Rejected
# 2023-11-09, Close, 37084.10
# 2023-11-09, BUY CREATE, 37084.10
# 2023-11-10, Order Canceled/Margin/Rejected
# 2023-11-10, Close, 37049.90
# 2023-11-10, BUY CREATE, 37049.90
# 2023-11-11, Order Canceled/Margin/Rejected
# 2023-11-11, Close, 37154.50
# 2023-11-11, BUY CREATE, 37154.50
# 2023-11-12, Order Canceled/Margin/Rejected
# 2023-11-12, Close, 36838.20
# 2023-11-12, BUY CREATE, 36838.20
# 2023-11-13, Order Canceled/Margin/Rejected
# 2023-11-13, Close, 36143.90
# 2023-11-13, BUY CREATE, 36143.90
# 2023-11-14, Order Canceled/Margin/Rejected
# 2023-11-14, Close, 36411.90
# 2023-11-14, BUY CREATE, 36411.90
# 2023-11-15, Order Canceled/Margin/Rejected
# 2023-11-15, Close, 36401.90
# 2023-11-15, BUY CREATE, 36401.90
# 2023-11-16, Order Canceled/Margin/Rejected
# 2023-11-16, Close, 36042.80
# 2023-11-16, BUY CREATE, 36042.80
# 2023-11-17, Order Canceled/Margin/Rejected
# 2023-11-17, Close, 36665.70
# 2023-11-17, BUY CREATE, 36665.70
# 2023-11-18, Order Canceled/Margin/Rejected
# 2023-11-18, Close, 36571.10
# 2023-11-18, BUY CREATE, 36571.10
# 2023-11-19, Order Canceled/Margin/Rejected
# 2023-11-19, Close, 37462.70
# 2023-11-19, BUY CREATE, 37462.70
# 2023-11-20, Order Canceled/Margin/Rejected
# 2023-11-20, Close, 36974.90
# 2023-11-20, BUY CREATE, 36974.90
# 2023-11-21, Order Canceled/Margin/Rejected
# 2023-11-21, Close, 36480.10
# 2023-11-21, BUY CREATE, 36480.10
# 2023-11-22, Order Canceled/Margin/Rejected
# 2023-11-22, Close, 36949.40
# 2023-11-22, BUY CREATE, 36949.40
# 2023-11-23, Order Canceled/Margin/Rejected
# 2023-11-23, Close, 38216.70
# 2023-11-23, BUY CREATE, 38216.70
# 2023-11-24, Order Canceled/Margin/Rejected
# 2023-11-24, Close, 37702.10
# 2023-11-24, BUY CREATE, 37702.10
# 2023-11-25, Order Canceled/Margin/Rejected
# 2023-11-25, Close, 37439.70
# 2023-11-25, BUY CREATE, 37439.70
# 2023-11-26, Order Canceled/Margin/Rejected
# 2023-11-26, Close, 36748.90
# 2023-11-27, Close, 37517.50
# 2023-11-27, BUY CREATE, 37517.50
# 2023-11-28, Order Canceled/Margin/Rejected
# 2023-11-28, Close, 37826.90
# 2023-11-28, BUY CREATE, 37826.90
# 2023-11-29, Order Canceled/Margin/Rejected
# 2023-11-29, Close, 37616.60
# 2023-11-29, BUY CREATE, 37616.60
# 2023-11-30, Order Canceled/Margin/Rejected
# 2023-11-30, Close, 38413.50
# 2023-11-30, BUY CREATE, 38413.50
# 2023-12-01, Order Canceled/Margin/Rejected
# 2023-12-01, Close, 38808.00
# 2023-12-01, BUY CREATE, 38808.00
# 2023-12-02, Order Canceled/Margin/Rejected
# 2023-12-02, Close, 39765.50
# 2023-12-02, BUY CREATE, 39765.50
# 2023-12-03, Order Canceled/Margin/Rejected
# 2023-12-03, Close, 41270.10
# 2023-12-03, BUY CREATE, 41270.10
# 2023-12-04, Order Canceled/Margin/Rejected
# 2023-12-04, Close, 42264.90
# 2023-12-04, BUY CREATE, 42264.90
# 2023-12-05, Order Canceled/Margin/Rejected
# 2023-12-05, Close, 43778.20
# 2023-12-05, BUY CREATE, 43778.20
# 2023-12-06, Order Canceled/Margin/Rejected
# 2023-12-06, Close, 43656.80
# 2023-12-06, BUY CREATE, 43656.80
# 2023-12-07, Order Canceled/Margin/Rejected
# 2023-12-07, Close, 43757.20
# 2023-12-07, BUY CREATE, 43757.20
# 2023-12-08, Order Canceled/Margin/Rejected
# 2023-12-08, Close, 44047.40
# 2023-12-08, BUY CREATE, 44047.40
# 2023-12-09, Order Canceled/Margin/Rejected
# 2023-12-09, Close, 43911.70
# 2023-12-09, BUY CREATE, 43911.70
# 2023-12-10, Order Canceled/Margin/Rejected
# 2023-12-10, Close, 41801.00
# 2023-12-10, BUY CREATE, 41801.00
# 2023-12-11, Order Canceled/Margin/Rejected
# 2023-12-11, Close, 41353.90
# 2023-12-11, BUY CREATE, 41353.90
# 2023-12-12, Order Canceled/Margin/Rejected
# 2023-12-12, Close, 41935.50
# 2023-12-12, BUY CREATE, 41935.50
# 2023-12-13, Order Canceled/Margin/Rejected
# 2023-12-13, Close, 42445.60
# 2023-12-13, BUY CREATE, 42445.60
# 2023-12-14, Order Canceled/Margin/Rejected
# 2023-12-14, Close, 41901.00
# 2023-12-14, BUY CREATE, 41901.00
# 2023-12-15, Order Canceled/Margin/Rejected
# 2023-12-15, Close, 42602.80
# 2023-12-15, BUY CREATE, 42602.80
# 2023-12-16, Order Canceled/Margin/Rejected
# 2023-12-16, Close, 41809.80
# 2023-12-16, BUY CREATE, 41809.80
# 2023-12-17, Order Canceled/Margin/Rejected
# 2023-12-17, Close, 41266.80
# 2023-12-18, Close, 42483.00
# 2023-12-18, BUY CREATE, 42483.00
# 2023-12-19, Order Canceled/Margin/Rejected
# 2023-12-19, Close, 44037.40
# 2023-12-19, BUY CREATE, 44037.40
# 2023-12-20, Order Canceled/Margin/Rejected
# 2023-12-20, Close, 43823.60
# 2023-12-20, BUY CREATE, 43823.60
# 2023-12-21, Order Canceled/Margin/Rejected
# 2023-12-21, Close, 43671.30
# 2023-12-21, BUY CREATE, 43671.30
# 2023-12-22, Order Canceled/Margin/Rejected
# 2023-12-22, Close, 43755.80
# 2023-12-22, BUY CREATE, 43755.80
# 2023-12-23, Order Canceled/Margin/Rejected
# 2023-12-23, Close, 43680.20
# 2023-12-23, BUY CREATE, 43680.20
# 2023-12-24, Order Canceled/Margin/Rejected
# 2023-12-24, Close, 43616.80
# 2023-12-24, BUY CREATE, 43616.80
# 2023-12-25, Order Canceled/Margin/Rejected
# 2023-12-25, Close, 42392.80
# 2023-12-26, Close, 42977.90
# 2023-12-26, BUY CREATE, 42977.90
# 2023-12-27, Order Canceled/Margin/Rejected
# 2023-12-27, Close, 42444.90
# 2023-12-28, Close, 42266.20
# 2023-12-29, Close, 42374.80
# 2023-12-30, Close, 42457.50
# 2023-12-31, Close, 42782.80
# 2023-12-31, BUY CREATE, 42782.80
# 2024-01-01, Order Canceled/Margin/Rejected
# 2024-01-01, Close, 45183.90
# 2024-01-01, BUY CREATE, 45183.90
# 2024-01-02, Order Canceled/Margin/Rejected
# 2024-01-02, Close, 42985.90
# 2024-01-02, BUY CREATE, 42985.90
# 2024-01-03, Order Canceled/Margin/Rejected
# 2024-01-03, Close, 44057.70
# 2024-01-03, BUY CREATE, 44057.70
# 2024-01-04, Order Canceled/Margin/Rejected
# 2024-01-04, Close, 43500.20
# 2024-01-04, BUY CREATE, 43500.20
# 2024-01-05, Order Canceled/Margin/Rejected
# 2024-01-05, Close, 43865.10
# 2024-01-05, BUY CREATE, 43865.10
# 2024-01-06, Order Canceled/Margin/Rejected
# 2024-01-06, Close, 44048.10
# 2024-01-06, BUY CREATE, 44048.10
# 2024-01-07, Order Canceled/Margin/Rejected
# 2024-01-07, Close, 44968.00
# 2024-01-07, BUY CREATE, 44968.00
# 2024-01-08, Order Canceled/Margin/Rejected
# 2024-01-08, Close, 46865.50
# 2024-01-08, BUY CREATE, 46865.50
# 2024-01-09, Order Canceled/Margin/Rejected
# 2024-01-09, Close, 45547.00
# 2024-01-09, BUY CREATE, 45547.00
# 2024-01-10, Order Canceled/Margin/Rejected
# 2024-01-10, Close, 46775.80
# 2024-01-10, BUY CREATE, 46775.80
# 2024-01-11, Order Canceled/Margin/Rejected
# 2024-01-11, Close, 44467.30
# 2024-01-11, BUY CREATE, 44467.30
# 2024-01-12, Order Canceled/Margin/Rejected
# 2024-01-12, Close, 43154.00
# 2024-01-13, Close, 42906.20
# 2024-01-14, Close, 42278.30
# 2024-01-15, Close, 43253.70
# 2024-01-16, Close, 42476.40
# 2024-01-17, Close, 42619.10
# 2024-01-18, Close, 40898.50
# 2024-01-19, Close, 41569.90
# 2024-01-20, Close, 41656.20
# 2024-01-21, Close, 40772.00
# 2024-01-22, Close, 39204.10
# 2024-01-23, Close, 40049.90
# 2024-01-24, Close, 39801.10
# 2024-01-25, Close, 41418.10
# 2024-01-26, Close, 41820.50
# 2024-01-27, Close, 42260.20
# 2024-01-28, Close, 42641.60
# 2024-01-28, BUY CREATE, 42641.60
# 2024-01-29, Order Canceled/Margin/Rejected
# 2024-01-29, Close, 43377.10
# 2024-01-29, BUY CREATE, 43377.10
# 2024-01-30, Order Canceled/Margin/Rejected
# 2024-01-30, Close, 43354.20
# 2024-01-30, BUY CREATE, 43354.20
# 2024-01-31, Order Canceled/Margin/Rejected
# 2024-01-31, Close, 42511.60
# 2024-01-31, BUY CREATE, 42511.60
# 2024-02-01, Order Canceled/Margin/Rejected
# 2024-02-01, Close, 43234.80
# 2024-02-01, BUY CREATE, 43234.80
# 2024-02-02, Order Canceled/Margin/Rejected
# 2024-02-02, Close, 43121.60
# 2024-02-02, BUY CREATE, 43121.60
# 2024-02-03, Order Canceled/Margin/Rejected
# 2024-02-03, Close, 42936.00
# 2024-02-03, BUY CREATE, 42936.00
# 2024-02-04, Order Canceled/Margin/Rejected
# 2024-02-04, Close, 42639.30
# 2024-02-04, BUY CREATE, 42639.30
# 2024-02-05, Order Canceled/Margin/Rejected
# 2024-02-05, Close, 43247.70
# 2024-02-05, BUY CREATE, 43247.70
# 2024-02-06, Order Canceled/Margin/Rejected
# 2024-02-06, Close, 43070.40
# 2024-02-06, BUY CREATE, 43070.40
# 2024-02-07, Order Canceled/Margin/Rejected
# 2024-02-07, Close, 45434.90
# 2024-02-07, BUY CREATE, 45434.90
# 2024-02-08, Order Canceled/Margin/Rejected
# 2024-02-08, Close, 47158.50
# 2024-02-08, BUY CREATE, 47158.50
# 2024-02-09, Order Canceled/Margin/Rejected
# 2024-02-09, Close, 47346.70
# 2024-02-09, BUY CREATE, 47346.70
# 2024-02-10, Order Canceled/Margin/Rejected
# 2024-02-10, Close, 48148.40
# 2024-02-10, BUY CREATE, 48148.40
# 2024-02-11, Order Canceled/Margin/Rejected
# 2024-02-11, Close, 49917.20
# 2024-02-11, BUY CREATE, 49917.20
# 2024-02-12, Order Canceled/Margin/Rejected
# 2024-02-12, Close, 48723.10
# 2024-02-12, BUY CREATE, 48723.10
# 2024-02-13, Order Canceled/Margin/Rejected
# 2024-02-13, Close, 51590.90
# 2024-02-13, BUY CREATE, 51590.90
# 2024-02-14, Order Canceled/Margin/Rejected
# 2024-02-14, Close, 51948.00
# 2024-02-14, BUY CREATE, 51948.00
# 2024-02-15, Order Canceled/Margin/Rejected
# 2024-02-15, Close, 51878.80
# 2024-02-15, BUY CREATE, 51878.80
# 2024-02-16, Order Canceled/Margin/Rejected
# 2024-02-16, Close, 50980.10
# 2024-02-16, BUY CREATE, 50980.10
# 2024-02-17, Order Canceled/Margin/Rejected
# 2024-02-17, Close, 51781.40
# 2024-02-17, BUY CREATE, 51781.40
# 2024-02-18, Order Canceled/Margin/Rejected
# 2024-02-18, Close, 52127.60
# 2024-02-18, BUY CREATE, 52127.60
# 2024-02-19, Order Canceled/Margin/Rejected
# 2024-02-19, Close, 51676.90
# 2024-02-19, BUY CREATE, 51676.90
# 2024-02-20, Order Canceled/Margin/Rejected
# 2024-02-20, Close, 51156.80
# 2024-02-20, BUY CREATE, 51156.80
# 2024-02-21, Order Canceled/Margin/Rejected
# 2024-02-21, Close, 51602.50
# 2024-02-21, BUY CREATE, 51602.50
# 2024-02-22, Order Canceled/Margin/Rejected
# 2024-02-22, Close, 50908.60
# 2024-02-22, BUY CREATE, 50908.60
# 2024-02-23, Order Canceled/Margin/Rejected
# 2024-02-23, Close, 51101.00
# 2024-02-23, BUY CREATE, 51101.00
# 2024-02-24, Order Canceled/Margin/Rejected
# 2024-02-24, Close, 51522.10
# 2024-02-24, BUY CREATE, 51522.10
# 2024-02-25, Order Canceled/Margin/Rejected
# 2024-02-25, Close, 52843.20
# 2024-02-25, BUY CREATE, 52843.20
# 2024-02-26, Order Canceled/Margin/Rejected
# 2024-02-26, Close, 56747.90
# 2024-02-26, BUY CREATE, 56747.90
# 2024-02-27, Order Canceled/Margin/Rejected
# 2024-02-27, Close, 60966.90
# 2024-02-27, BUY CREATE, 60966.90
# 2024-02-28, Order Canceled/Margin/Rejected
# 2024-02-28, Close, 62764.20
# 2024-02-28, BUY CREATE, 62764.20
# 2024-02-29, Order Canceled/Margin/Rejected
# 2024-02-29, Close, 61272.50
# 2024-02-29, BUY CREATE, 61272.50
# 2024-03-01, Order Canceled/Margin/Rejected
# 2024-03-01, Close, 61776.70
# 2024-03-01, BUY CREATE, 61776.70
# 2024-03-02, Order Canceled/Margin/Rejected
# 2024-03-02, Close, 62172.10
# 2024-03-02, BUY CREATE, 62172.10
# 2024-03-03, Order Canceled/Margin/Rejected
# 2024-03-03, Close, 66454.10
# 2024-03-03, BUY CREATE, 66454.10
# 2024-03-04, Order Canceled/Margin/Rejected
# 2024-03-04, Close, 66778.00
# 2024-03-04, BUY CREATE, 66778.00
# 2024-03-05, Order Canceled/Margin/Rejected
# 2024-03-05, Close, 66485.70
# 2024-03-05, BUY CREATE, 66485.70
# 2024-03-06, Order Canceled/Margin/Rejected
# 2024-03-06, Close, 67261.80
# 2024-03-06, BUY CREATE, 67261.80
# 2024-03-07, Order Canceled/Margin/Rejected
# 2024-03-07, Close, 67618.10
# 2024-03-07, BUY CREATE, 67618.10
# 2024-03-08, Order Canceled/Margin/Rejected
# 2024-03-08, Close, 68288.80
# 2024-03-08, BUY CREATE, 68288.80
# 2024-03-09, Order Canceled/Margin/Rejected
# 2024-03-09, Close, 69191.50
# 2024-03-09, BUY CREATE, 69191.50
# 2024-03-10, Order Canceled/Margin/Rejected
# 2024-03-10, Close, 72008.00
# 2024-03-10, BUY CREATE, 72008.00
# 2024-03-11, Order Canceled/Margin/Rejected
# 2024-03-11, Close, 71702.00
# 2024-03-11, BUY CREATE, 71702.00
# 2024-03-12, Order Canceled/Margin/Rejected
# 2024-03-12, Close, 72624.10
# 2024-03-12, BUY CREATE, 72624.10
# 2024-03-13, Order Canceled/Margin/Rejected
# 2024-03-13, Close, 70843.30
# 2024-03-13, BUY CREATE, 70843.30
# 2024-03-14, Order Canceled/Margin/Rejected
# 2024-03-14, Close, 68165.30
# 2024-03-14, BUY CREATE, 68165.30
# 2024-03-15, Order Canceled/Margin/Rejected
# 2024-03-15, Close, 68385.80
# 2024-03-15, BUY CREATE, 68385.80
# 2024-03-16, Order Canceled/Margin/Rejected
# 2024-03-16, Close, 67963.80
# 2024-03-16, BUY CREATE, 67963.80
# 2024-03-17, Order Canceled/Margin/Rejected
# 2024-03-17, Close, 67480.00
# 2024-03-17, BUY CREATE, 67480.00
# 2024-03-18, Order Canceled/Margin/Rejected
# 2024-03-18, Close, 64056.90
# 2024-03-19, Close, 63607.70
# 2024-03-20, Close, 66571.20
# 2024-03-21, Close, 63883.90
# 2024-03-22, Close, 65099.90
# 2024-03-23, Close, 65673.10
# 2024-03-24, Close, 69785.70
# 2024-03-24, BUY CREATE, 69785.70
# 2024-03-25, Order Canceled/Margin/Rejected
# 2024-03-25, Close, 70257.00
# 2024-03-25, BUY CREATE, 70257.00
# 2024-03-26, Order Canceled/Margin/Rejected
# 2024-03-26, Close, 68882.10
# 2024-03-26, BUY CREATE, 68882.10
# 2024-03-27, Order Canceled/Margin/Rejected
# 2024-03-27, Close, 71289.80
# 2024-03-27, BUY CREATE, 71289.80
# 2024-03-28, Order Canceled/Margin/Rejected
# 2024-03-28, Close, 69176.60
# 2024-03-28, BUY CREATE, 69176.60
# 2024-03-29, Order Canceled/Margin/Rejected
# 2024-03-29, Close, 70002.00
# 2024-03-29, BUY CREATE, 70002.00
# 2024-03-30, Order Canceled/Margin/Rejected
# 2024-03-30, Close, 70394.00
# 2024-03-30, BUY CREATE, 70394.00
# 2024-03-31, Order Canceled/Margin/Rejected
# 2024-03-31, Close, 68230.00
# 2024-03-31, BUY CREATE, 68230.00
# 2024-04-01, Order Canceled/Margin/Rejected
# 2024-04-01, Close, 64876.00
# 2024-04-02, Close, 65836.70
# 2024-04-03, Close, 67649.80
# 2024-04-03, BUY CREATE, 67649.80
# 2024-04-04, Order Canceled/Margin/Rejected
# 2024-04-04, Close, 68201.40
# 2024-04-04, BUY CREATE, 68201.40
# 2024-04-05, Order Canceled/Margin/Rejected
# 2024-04-05, Close, 68112.80
# 2024-04-05, BUY CREATE, 68112.80
# 2024-04-06, Order Canceled/Margin/Rejected
# 2024-04-06, Close, 69555.90
# 2024-04-06, BUY CREATE, 69555.90
# 2024-04-07, Order Canceled/Margin/Rejected
# 2024-04-07, Close, 71782.20
# 2024-04-07, BUY CREATE, 71782.20
# 2024-04-08, Order Canceled/Margin/Rejected
# 2024-04-08, Close, 69264.60
# 2024-04-08, BUY CREATE, 69264.60
# 2024-04-09, Order Canceled/Margin/Rejected
# 2024-04-09, Close, 68656.00
# 2024-04-09, BUY CREATE, 68656.00
# 2024-04-10, Order Canceled/Margin/Rejected
# 2024-04-10, Close, 70001.30
# 2024-04-10, BUY CREATE, 70001.30
# 2024-04-11, Order Canceled/Margin/Rejected
# 2024-04-11, Close, 69346.10
# 2024-04-11, BUY CREATE, 69346.10
# 2024-04-12, Order Canceled/Margin/Rejected
# 2024-04-12, Close, 67672.10
# 2024-04-13, Close, 64173.30
# 2024-04-14, Close, 64568.10
# 2024-04-15, Close, 61758.90
# 2024-04-16, Close, 60299.40
# 2024-04-17, Close, 63498.20
# 2024-04-18, Close, 64439.70
# 2024-04-19, Close, 64806.00
# 2024-04-20, Close, 65043.90
# 2024-04-21, Close, 66002.40
# 2024-04-22, Close, 66422.70
# 2024-04-23, Close, 64615.50
# 2024-04-24, Close, 64132.10
# 2024-04-25, Close, 63503.70
# 2024-04-26, Close, 62955.80
# 2024-04-27, Close, 63536.40
# 2024-04-28, Close, 63045.30
# 2024-04-29, Close, 60793.90
# 2024-04-30, Close, 56885.30
# 2024-05-01, Close, 59266.30
# 2024-05-02, Close, 61690.00
# 2024-05-03, Close, 63612.40
# 2024-05-03, BUY CREATE, 63612.40
# 2024-05-04, Order Canceled/Margin/Rejected
# 2024-05-04, Close, 64432.00
# 2024-05-04, BUY CREATE, 64432.00
# 2024-05-05, Order Canceled/Margin/Rejected
# 2024-05-05, Close, 63632.40
# 2024-05-05, BUY CREATE, 63632.40
# 2024-05-06, Order Canceled/Margin/Rejected
# 2024-05-06, Close, 63741.90
# 2024-05-06, BUY CREATE, 63741.90
# 2024-05-07, Order Canceled/Margin/Rejected
# 2024-05-07, Close, 62278.00
# 2024-05-08, Close, 62157.80
# 2024-05-09, Close, 60925.00
# 2024-05-10, Close, 61176.10
# 2024-05-11, Close, 61411.70
# 2024-05-12, Close, 63009.90
# 2024-05-12, BUY CREATE, 63009.90
# 2024-05-13, Order Canceled/Margin/Rejected
# 2024-05-13, Close, 61779.80
# 2024-05-14, Close, 64714.10
# 2024-05-14, BUY CREATE, 64714.10
# 2024-05-15, Order Canceled/Margin/Rejected
# 2024-05-15, Close, 65826.10
# 2024-05-15, BUY CREATE, 65826.10
# 2024-05-16, Order Canceled/Margin/Rejected
# 2024-05-16, Close, 67199.00
# 2024-05-16, BUY CREATE, 67199.00
# 2024-05-17, Order Canceled/Margin/Rejected
# 2024-05-17, Close, 66813.60
# 2024-05-17, BUY CREATE, 66813.60
# 2024-05-18, Order Canceled/Margin/Rejected
# 2024-05-18, Close, 66887.50
# 2024-05-18, BUY CREATE, 66887.50
# 2024-05-19, Order Canceled/Margin/Rejected
# 2024-05-19, Close, 67413.80
# 2024-05-19, BUY CREATE, 67413.80
# 2024-05-20, Order Canceled/Margin/Rejected
# 2024-05-20, Close, 69821.50
# 2024-05-20, BUY CREATE, 69821.50
# 2024-05-21, Order Canceled/Margin/Rejected
# 2024-05-21, Close, 70451.60
# 2024-05-21, BUY CREATE, 70451.60
# 2024-05-22, Order Canceled/Margin/Rejected
# 2024-05-22, Close, 68075.50
# 2024-05-22, BUY CREATE, 68075.50
# 2024-05-23, Order Canceled/Margin/Rejected
# 2024-05-23, Close, 68332.00
# 2024-05-23, BUY CREATE, 68332.00
# 2024-05-24, Order Canceled/Margin/Rejected
# 2024-05-24, Close, 68938.60
# 2024-05-24, BUY CREATE, 68938.60
# 2024-05-25, Order Canceled/Margin/Rejected
# 2024-05-25, Close, 68846.40
# 2024-05-25, BUY CREATE, 68846.40
# 2024-05-26, Order Canceled/Margin/Rejected
# 2024-05-26, Close, 70370.80
# 2024-05-26, BUY CREATE, 70370.80
# 2024-05-27, Order Canceled/Margin/Rejected
# 2024-05-27, Close, 68379.40
# 2024-05-27, BUY CREATE, 68379.40
# 2024-05-28, Order Canceled/Margin/Rejected
# 2024-05-28, Close, 67380.00
# 2024-05-28, BUY CREATE, 67380.00
# 2024-05-29, Order Canceled/Margin/Rejected
# 2024-05-29, Close, 68532.10
# 2024-05-29, BUY CREATE, 68532.10
# 2024-05-30, Order Canceled/Margin/Rejected
# 2024-05-30, Close, 67209.60
# 2024-05-30, BUY CREATE, 67209.60
# 2024-05-31, Order Canceled/Margin/Rejected
# 2024-05-31, Close, 67683.90
# 2024-05-31, BUY CREATE, 67683.90
# 2024-06-01, Order Canceled/Margin/Rejected
# 2024-06-01, Close, 68147.10
# 2024-06-01, BUY CREATE, 68147.10
# 2024-06-02, Order Canceled/Margin/Rejected
# 2024-06-02, Close, 69613.30
# 2024-06-02, BUY CREATE, 69613.30
# 2024-06-03, Order Canceled/Margin/Rejected
# 2024-06-03, Close, 70447.90
# 2024-06-03, BUY CREATE, 70447.90
# 2024-06-04, Order Canceled/Margin/Rejected
# 2024-06-04, Close, 71567.30
# 2024-06-04, BUY CREATE, 71567.30
# 2024-06-05, Order Canceled/Margin/Rejected
# 2024-06-05, Close, 71302.20
# 2024-06-05, BUY CREATE, 71302.20
# 2024-06-06, Order Canceled/Margin/Rejected
# 2024-06-06, Close, 71108.60
# 2024-06-06, BUY CREATE, 71108.60
# 2024-06-07, Order Canceled/Margin/Rejected
# 2024-06-07, Close, 69420.80
# 2024-06-07, BUY CREATE, 69420.80
# 2024-06-08, Order Canceled/Margin/Rejected
# 2024-06-08, Close, 69508.50
# 2024-06-08, BUY CREATE, 69508.50
# 2024-06-09, Order Canceled/Margin/Rejected
# 2024-06-09, Close, 70058.60
# 2024-06-09, BUY CREATE, 70058.60
# 2024-06-10, Order Canceled/Margin/Rejected
# 2024-06-10, Close, 66230.30
# 2024-06-11, Close, 69728.90
# 2024-06-11, BUY CREATE, 69728.90
# 2024-06-12, Order Canceled/Margin/Rejected
# 2024-06-12, Close, 66460.00
# 2024-06-13, Close, 66388.30
# 2024-06-14, Close, 66317.50
# 2024-06-15, Close, 66705.40
# 2024-06-16, Close, 65365.20
# 2024-06-17, Close, 64702.30
# 2024-06-18, Close, 64929.00
# 2024-06-19, Close, 64832.00
# 2024-06-20, Close, 63724.10
# 2024-06-21, Close, 64302.90
# 2024-06-22, Close, 64097.90
# 2024-06-23, Close, 60850.00
# 2024-06-24, Close, 61820.60
# 2024-06-25, Close, 61480.00
# 2024-06-26, Close, 61590.10
# 2024-06-27, Close, 61060.00
# 2024-06-28, Close, 61115.10
# 2024-06-29, Close, 61719.80
# 2024-06-30, Close, 63142.10
# 2024-07-01, Close, 61949.90
# 2024-07-02, Close, 60183.00
# 2024-07-03, Close, 58143.30
# 2024-07-04, Close, 56670.10
# 2024-07-05, Close, 57320.20
# 2024-07-06, Close, 56826.00
# 2024-07-07, Close, 55760.90
# 2024-07-08, Close, 57476.90
# 2024-07-09, Close, 57700.10
# 2024-07-10, Close, 57405.80
# 2024-07-11, Close, 58211.90
# 2024-07-12, Close, 58838.10
# 2024-07-13, Close, 60088.20
# 2024-07-13, BUY CREATE, 60088.20
# 2024-07-14, Order Canceled/Margin/Rejected
# 2024-07-14, Close, 63031.40
# 2024-07-14, BUY CREATE, 63031.40
# 2024-07-15, Order Canceled/Margin/Rejected
# 2024-07-15, Close, 64888.20
# 2024-07-15, BUY CREATE, 64888.20
# 2024-07-16, Order Canceled/Margin/Rejected
# 2024-07-16, Close, 64728.90
# 2024-07-16, BUY CREATE, 64728.90
# 2024-07-17, Order Canceled/Margin/Rejected
# 2024-07-17, Close, 63537.40
# 2024-07-17, BUY CREATE, 63537.40
# 2024-07-18, Order Canceled/Margin/Rejected
# 2024-07-18, Close, 65836.70
# 2024-07-18, BUY CREATE, 65836.70
# 2024-07-19, Order Canceled/Margin/Rejected
# 2024-07-19, Close, 66827.10
# 2024-07-19, BUY CREATE, 66827.10
# 2024-07-20, Order Canceled/Margin/Rejected
# 2024-07-20, Close, 67167.50
# 2024-07-20, BUY CREATE, 67167.50
# 2024-07-21, Order Canceled/Margin/Rejected
# 2024-07-21, Close, 67065.30
# 2024-07-21, BUY CREATE, 67065.30
# 2024-07-22, Order Canceled/Margin/Rejected
# 2024-07-22, Close, 66583.00
# 2024-07-22, BUY CREATE, 66583.00
# 2024-07-23, Order Canceled/Margin/Rejected
# 2024-07-23, Close, 66177.50
# 2024-07-23, BUY CREATE, 66177.50
# 2024-07-24, Order Canceled/Margin/Rejected
# 2024-07-24, Close, 64778.00
# 2024-07-24, BUY CREATE, 64778.00
# 2024-07-25, Order Canceled/Margin/Rejected
# 2024-07-25, Close, 67562.90
# 2024-07-25, BUY CREATE, 67562.90
# 2024-07-26, Order Canceled/Margin/Rejected
# 2024-07-26, Close, 68862.50
# 2024-07-26, BUY CREATE, 68862.50
# 2024-07-27, Order Canceled/Margin/Rejected
# 2024-07-27, Close, 67645.80
# 2024-07-27, BUY CREATE, 67645.80
# 2024-07-28, Order Canceled/Margin/Rejected
# 2024-07-28, Close, 68100.00
# 2024-07-28, BUY CREATE, 68100.00
# 2024-07-29, Order Canceled/Margin/Rejected
# 2024-07-29, Close, 66217.90
# 2024-07-29, BUY CREATE, 66217.90
# 2024-07-30, Order Canceled/Margin/Rejected
# 2024-07-30, Close, 66385.90
# 2024-07-30, BUY CREATE, 66385.90
# 2024-07-31, Order Canceled/Margin/Rejected
# 2024-07-31, Close, 62902.00
# 2024-08-01, Close, 63418.60
# 2024-08-02, Close, 60878.30
# 2024-08-03, Close, 59087.70
# 2024-08-04, Close, 54318.00
# 2024-08-05, Close, 56412.60
# 2024-08-06, Close, 56092.70
# 2024-08-07, Close, 59429.90
# 2024-08-08, Close, 59812.90
# 2024-08-09, Close, 60523.90
# 2024-08-10, Close, 60127.90
# 2024-08-11, Close, 60207.20
# 2024-08-12, Close, 59480.10
# 2024-08-13, Close, 59443.80
# 2024-08-14, Close, 59675.80
# 2024-08-15, Close, 58074.10
# 2024-08-16, Close, 59394.30
# 2024-08-17, Close, 59863.40
# 2024-08-18, Close, 58540.00
# 2024-08-19, Close, 58831.40
# 2024-08-20, Close, 59518.70
# 2024-08-20, BUY CREATE, 59518.70
# 2024-08-21, Order Canceled/Margin/Rejected
# 2024-08-21, Close, 60407.10
# 2024-08-21, BUY CREATE, 60407.10
# 2024-08-22, Order Canceled/Margin/Rejected
# 2024-08-22, Close, 61534.00
# 2024-08-22, BUY CREATE, 61534.00
# 2024-08-23, Order Canceled/Margin/Rejected
# 2024-08-23, Close, 63984.10
# 2024-08-23, BUY CREATE, 63984.10
# 2024-08-24, Order Canceled/Margin/Rejected
# 2024-08-24, Close, 64133.50
# 2024-08-24, BUY CREATE, 64133.50
# 2024-08-25, Order Canceled/Margin/Rejected
# 2024-08-25, Close, 63534.00
# 2024-08-25, BUY CREATE, 63534.00
# 2024-08-26, Order Canceled/Margin/Rejected
# 2024-08-26, Close, 61704.00
# 2024-08-26, BUY CREATE, 61704.00
# 2024-08-27, Order Canceled/Margin/Rejected
# 2024-08-27, Close, 59002.40
# 2024-08-28, Close, 60777.40
# 2024-08-28, BUY CREATE, 60777.40
# 2024-08-29, Order Canceled/Margin/Rejected
# 2024-08-29, Close, 58088.00
# 2024-08-30, Close, 59013.80
# 2024-08-31, Close, 58214.10
# 2024-09-01, Close, 58535.70
# 2024-09-02, Close, 57724.00
# 2024-09-03, Close, 58128.70
# 2024-09-04, Close, 55976.10
# 2024-09-05, Close, 54044.00
# 2024-09-06, Close, 54784.10
# 2024-09-07, Close, 53687.90
# 2024-09-08, Close, 55383.90
# 2024-09-09, Close, 56592.20
# 2024-09-10, Close, 56700.40
# 2024-09-11, Close, 57514.20
# 2024-09-12, Close, 59660.10
# 2024-09-12, BUY CREATE, 59660.10
# 2024-09-13, Order Canceled/Margin/Rejected
# 2024-09-13, Close, 59875.30
# 2024-09-13, BUY CREATE, 59875.30
# 2024-09-14, Order Canceled/Margin/Rejected
# 2024-09-14, Close, 60334.20
# 2024-09-14, BUY CREATE, 60334.20
# 2024-09-15, Order Canceled/Margin/Rejected
# 2024-09-15, Close, 57881.80
# 2024-09-15, BUY CREATE, 57881.80
# 2024-09-16, Order Canceled/Margin/Rejected
# 2024-09-16, Close, 61134.00
# 2024-09-16, BUY CREATE, 61134.00
# 2024-09-17, Order Canceled/Margin/Rejected
# 2024-09-17, Close, 59430.00
# 2024-09-17, BUY CREATE, 59430.00
# 2024-09-18, Order Canceled/Margin/Rejected
# 2024-09-18, Close, 63156.20
# 2024-09-18, BUY CREATE, 63156.20
# 2024-09-19, Order Canceled/Margin/Rejected
# 2024-09-19, Close, 63160.00
# 2024-09-19, BUY CREATE, 63160.00
# 2024-09-20, Order Canceled/Margin/Rejected
# 2024-09-20, Close, 63170.10
# 2024-09-20, BUY CREATE, 63170.10
# 2024-09-21, Order Canceled/Margin/Rejected
# 2024-09-21, Close, 62656.10
# 2024-09-21, BUY CREATE, 62656.10
# 2024-09-22, Order Canceled/Margin/Rejected
# 2024-09-22, Close, 63616.10
# 2024-09-22, BUY CREATE, 63616.10
# 2024-09-23, Order Canceled/Margin/Rejected
# 2024-09-23, Close, 63160.00
# 2024-09-23, BUY CREATE, 63160.00
# 2024-09-24, Order Canceled/Margin/Rejected
# 2024-09-24, Close, 63499.00
# 2024-09-24, BUY CREATE, 63499.00
# Final Portfolio Value: 100000.00
# <div id='1f6a4aa2-48e1-47de-9287-4d7c359faf09'></div>
